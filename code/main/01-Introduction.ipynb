# %% [markdown]
# # Euclidean elections: do the rules agree?
#
# Voters and candidates are points in the plane; each voter ranks the candidates by distance.

# %%
import sys

sys.path.append("..")

import random

import matplotlib.pyplot as plt
import numpy as np

# %%
from voting import (
    BordaRule,
    Candidate,
    Election,
    ElectionResult,
    PluralityRule,
    ResultsAnalyzer,
    VetoRule,
    Voter,
)

from voting.plotting import (
    plot_election,
    plot_result,
    plot_winner_distances,
    random_2d_point,
    random_2d_points,
)

RULES = [PluralityRule(), BordaRule(), VetoRule()]

# %% [markdown]
# ## One election, up close
#
# `plot_election` takes bare coordinate arrays, so it works before any `Election`
# object exists.

# %%
plot_election(random_2d_points(), random_2d_points())
# Out:
# <Axes: title={'center': 'Voter Distribution in Euclidean Space (5 voters)'}>

# %%
candidates = [Candidate(id=id, position=random_2d_point()) for id in range(5)]
voters = [Voter(position=random_2d_point()) for _ in range(15)]

election = Election(candidates=candidates, voters=voters)
result = election.compare(RULES)

print("winners:", result.winner_indices())
print("any rule tied:", result.has_tie())
# Out:
# winners: {'plurality': 1, 'borda': 1, 'veto': 1}
# any rule tied: True

# %%
result.tally("veto").top_indices
# Out:
# [1, 3]

# %% [markdown]
# The plot marks each rule's winner with its own colour, so the cases where the rules
# disagree are the ones with several dots.

# %%
plot_result(result)
# Out:
# <Axes: title={'center': 'Voter Distribution in Euclidean Space (15 voters)'}>

# %% [markdown]
# ## When are the rules decisive?
#
# A tied tally has no winner - `Tally.winner_index` falls back to the lowest index,
# which is an arbitrary choice, not an outcome. So before averaging anything over
# many elections it is worth knowing how often each rule actually decides.

# %%
def tie_rates(n_candidates, n_voters, trials=200, rng=None):
    """How often each rule ties, and how often at least one of them does."""
    rng = rng or np.random.default_rng(0)
    tied = {rule.key: 0 for rule in RULES}
    any_tied = 0

    for _ in range(trials):
        cand = rng.uniform(-10, 10, (n_candidates, 2))
        vot = rng.uniform(-10, 10, (n_voters, 2))
        outcome = Election(cand, vot).compare(RULES)
        for rule in RULES:
            tied[rule.key] += outcome.tally(rule).is_tie()
        any_tied += outcome.has_tie()

    return {key: count / trials for key, count in tied.items()}, any_tied / trials


print(f"{'M':>4}{'N':>7}" + "".join(f"{r.name:>12}" for r in RULES) + f"{'any':>8}")
for n_candidates, n_voters in [(3, 200), (4, 500), (5, 500), (8, 500), (50, 100)]:
    rates, any_rate = tie_rates(n_candidates, n_voters)
    row = "".join(f"{rates[r.key]:>11.0%} " for r in RULES)
    print(f"{n_candidates:>4}{n_voters:>7}{row}{any_rate:>7.0%}")
# Out:
#    M      NPlurality rule Borda count   Veto rule     any
#    3    200         1%          0%          0%      2%
#    4    500         1%          0%         12%     14%
#    5    500         1%          0%         49%     50%
#    8    500         2%          0%        100%    100%
#   50    100        26%          1%        100%    100%

# %% [markdown]
# Veto is the whole problem, and more voters do not help - it is structural.
#
# Veto gives 0 points to a voter's **farthest** candidate, and the farthest point
# from anywhere is always a vertex of the convex hull of the candidates. So only the hull
# candidates can ever be vetoed, and **every candidate strictly inside the hull
# scores the maximum**, all tied together.
#
# With 50 candidates that is essentially all of them.

# %%
cand = np.random.default_rng(1).uniform(-10, 10, (50, 2))
vot = np.random.default_rng(2).uniform(-10, 10, (100, 2))

distances = np.linalg.norm(vot[:, None, :] - cand[None, :, :], axis=2)
vetoed = np.unique(distances.argmax(axis=1))

print(f"candidates that are somebody's farthest: {len(vetoed)} of {len(cand)}")
print(f"candidates tied at the top of veto:      {len(cand) - len(vetoed)}")

outcome = Election(cand, vot).compare(RULES)
print(f"veto tally tied: {outcome.tally('veto').is_tie()}, "
      f"margin: {outcome.tally('veto').margin}")
# Out:
# candidates that are somebody's farthest: 8 of 50
# candidates tied at the top of veto:      42
# veto tally tied: True, margin: 0.0

# %% [markdown]
# ## Winner dispersion across many elections
#
# Given the table above, the sweep runs at **4 candidates**, where veto ties only
# about one election in ten. Tied elections are kept out of the dispersion
# statistics: their "winner" is an index, not a result.

# %%
N_ELECTIONS = 1000
N_CANDIDATES = 4
N_VOTERS = 500

decisive: list[ElectionResult] = []
n_tied = 0

for _ in range(N_ELECTIONS):
    candidates = [
        Candidate(id=id, position=random_2d_point()) for id in range(N_CANDIDATES)
    ]
    voters = [Voter(position=random_2d_point()) for _ in range(N_VOTERS)]
    outcome = Election(candidates=candidates, voters=voters).compare(RULES)

    if outcome.has_tie():
        n_tied += 1
    else:
        decisive.append(outcome)

print(f"tied (excluded):  {n_tied}/{N_ELECTIONS} ({n_tied / N_ELECTIONS:.1%})")
print(f"decisive (kept):  {len(decisive)}")
# Out:
# tied (excluded):  102/1000 (10.2%)
# decisive (kept):  898

# %%
analyzer = ResultsAnalyzer(decisive)
distances = analyzer.winner_distance_series()

print(f"rules disagreed in {analyzer.disagreement_rate():.1%} of the decisive elections")
print(f"mean distance between winners: {np.mean(distances):.3f}")

plot_winner_distances(distances, bins=30)
# Out:
# rules disagreed in 68.7% of the decisive elections
# mean distance between winners: 4.575
# <Axes: title={'center': 'Distribution of winner dispersion across strategies'}, xlabel='Average distance between winners', ylabel='Number of elections'>

# %% [markdown]
# The extremes of that histogram are the interesting elections: the one where
# the rules landed furthest apart, and the one where they agreed most closely.

# %%
furthest = decisive[int(np.argmax(distances))]
closest = decisive[int(np.argmin(distances))]

fig, (left, right) = plt.subplots(1, 2, figsize=(15, 7))
plot_result(furthest, color_voters=True, ax=left)
left.set_title(f"Winners furthest apart ({max(distances):.2f})")
plot_result(closest, color_voters=True,ax=right)
right.set_title(f"Winners closest together ({min(distances):.2f})")
plt.tight_layout()
plt.show()

fig, (left, right) = plt.subplots(1, 2, figsize=(15, 7))
plot_result(furthest, regions=True, ax=left)
left.set_title(f"Winners furthest apart ({max(distances):.2f})")
plot_result(closest, regions=True, ax=right)
right.set_title(f"Winners closest together ({min(distances):.2f})")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Nested Monte Carlo. Random candidates AND random voters
#
# The outer loop draws candidate configurations; the inner loop draws voter samples
# per configuration. This separates *within-config* variance (sensitivity to the
# voter draw) from *across-config* variance (sensitivity to where the candidates
# sit).
#
# `ResultsAnalyzer` is reused unchanged - instantiated per group for within-config
# statistics, and once over the flat list for the overall picture.

# %%
N_CONFIGS = 200
N_VOTER_SAMPLES = 20

groups: list[list[ElectionResult]] = []
n_total = n_tied = 0

for _ in range(N_CONFIGS):
    candidates = [
        Candidate(id=id, position=random_2d_point()) for id in range(N_CANDIDATES)
    ]

    group: list[ElectionResult] = []
    for _ in range(N_VOTER_SAMPLES):
        voters = [Voter(position=random_2d_point()) for _ in range(N_VOTERS)]
        outcome = Election(candidates=candidates, voters=voters).compare(RULES)
        n_total += 1
        if outcome.has_tie():
            n_tied += 1
        else:
            group.append(outcome)

    if group:  # a configuration can lose every draw to ties
        groups.append(group)

print(f"tied (excluded): {n_tied}/{n_total} ({n_tied / n_total:.1%})")
print(f"configurations with at least one decisive draw: {len(groups)}/{N_CONFIGS}")
# Out:
# tied (excluded): 407/4000 (10.2%)
# configurations with at least one decisive draw: 184/200

# %%
per_config_mean = []
per_config_std = []

for group in groups:
    group_distances = ResultsAnalyzer(group).winner_distance_series()
    per_config_mean.append(float(np.mean(group_distances)))
    per_config_std.append(float(np.std(group_distances)))

flat = [outcome for group in groups for outcome in group]
flat_distances = ResultsAnalyzer(flat).winner_distance_series()

print(f"Overall mean winner-distance:        {np.mean(flat_distances):.3f}")
print(f"Std across all draws (pooled):       {np.std(flat_distances):.3f}")
print(f"Std of per-config means (between):   {np.std(per_config_mean):.3f}")
print(f"Mean of per-config stds (within):    {np.mean(per_config_std):.3f}")
# Out:
# Overall mean winner-distance:        4.446
# Std across all draws (pooled):       3.963
# Std of per-config means (between):   3.653
# Mean of per-config stds (within):    0.745

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(flat_distances, bins=30, edgecolor="black")
axes[0].set_title("Pooled (all draws)")
axes[0].set_xlabel("Mean winner-distance")
axes[0].set_ylabel("Count")

axes[1].hist(per_config_mean, bins=30, edgecolor="black", color="orange")
axes[1].set_title("Per-config means")
axes[1].set_xlabel("Mean winner-distance (averaged over voter draws)")
axes[1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %% [markdown]
# Between-config variance dominating within-config variance would mean the candidate layout matters more than the voter draw - which is what makes the search for *layouts* that spread the winners worth doing at all.

# %%
worst = groups[int(np.argmax(per_config_mean))]
best = groups[int(np.argmin(per_config_mean))]

worst_distances = ResultsAnalyzer(worst).winner_distance_series()
best_distances = ResultsAnalyzer(best).winner_distance_series()

fig, (left, right) = plt.subplots(1, 2, figsize=(15, 7))
plot_result(worst[int(np.argmax(worst_distances))], regions=True, ax=left)
left.set_title("Most disagreeing configuration")
plot_result(best[int(np.argmin(best_distances))], regions=True, ax=right)
right.set_title("Least disagreeing configuration")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Does clustering the voters change anything?
#
# Uniform voters are the easy case. Real electorates clump, and clumping splits support between nearby candidates.
#
# Watch the `decisive` column as much as the other two: clumping makes ties markedly more common, because a clump that sits far from one candidate makes that candidate everybody's last choice and flattens the veto tally.

# %%
def cluster_point(centers, std=0.7, weights=None):
    """One voter drawn from a mixture of Gaussian clumps."""
    center = random.choices(centers, weights=weights)[0]
    return (random.gauss(center[0], std), random.gauss(center[1], std))


def sweep(draw_voters, trials=400):
    """Disagreement rate and mean winner-distance over decisive elections."""
    decisive = []
    for _ in range(trials):
        candidates = [
            Candidate(id=id, position=random_2d_point()) for id in range(N_CANDIDATES)
        ]
        voters = [Voter(position=p) for p in draw_voters()]
        outcome = Election(candidates=candidates, voters=voters).compare(RULES)
        if not outcome.has_tie():
            decisive.append(outcome)

    analyzer = ResultsAnalyzer(decisive)
    return len(decisive), analyzer.disagreement_rate(), analyzer.winner_distance_series()


CORNERS = [(-5, -5), (5, -5), (-5, 5), (5, 5)]

layouts = {
    "uniform": lambda: [random_2d_point() for _ in range(N_VOTERS)],
    "2 clumps": lambda: [cluster_point(CORNERS[:2], std=1.5) for _ in range(N_VOTERS)],
    "4 clumps": lambda: [cluster_point(CORNERS, std=1.5) for _ in range(N_VOTERS)],
}

print(f"{'voters':>10}{'decisive':>10}{'disagree':>10}{'mean dist':>11}")
for label, draw in layouts.items():
    kept, disagreement, dists = sweep(draw)
    print(f"{label:>10}{kept:>10}{disagreement:>9.0%}{np.mean(dists):>11.3f}")
# Out:
#     voters  decisive  disagree  mean dist
#    uniform       366      69%      4.562
#   2 clumps       185      58%      3.870
#   4 clumps       329      66%      4.291
